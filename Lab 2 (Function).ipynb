# %%
def div_frac(x, y):
    
    if y == 0:
        return 0
    else:
        result = (x / y) - (x // y)
        if result == 0.0:
            return 0
        else:
            return result

print(div_frac(5, 2))
print(div_frac(5, 0))
print(div_frac(3, 7))
# Out:
# 0.5
# 0
# 0.42857142857142855

# %%
5//2
# Out:
# 2

# %%
#Task 2

def BMI(height, weight):
  height=height/100
  bmi =round(weight/height**2,1)
  ans = ""
  if bmi<18.5:
    ans = "Underweight"
  elif 18.5<=bmi<=24.9:
    ans = "Normal"
  elif 25<= bmi<=30:
    ans= "Overweight"
  else:
    ans = "Obese"
  final = "score is "+str(bmi)+" You are "+ans
  return final
BMI(175, 96)
# Out:
# 'score is 31.3 You are Obese'

# %%
#task 3

def add(x,y,z):
  sum = 0

  for i in range(x,y):
    if i%z==0:
      sum+=i
  return sum
add(0,10,2)
# Out:
# 20

# %%
# Task 4
def total(name,location="Mohakhali"):
  price = 0
  if name=="BBQ Chicken Cheese Burger":
    price+=250
  elif name=="beef burger":
    price+=170
  elif name == "Naga drums":
    price+=200
  tax = price+price*(8/100)

  if location=="Mohakhali":
    tax+=40
  else:
    tax+=60
  return tax
total('beef burger',"Dhanmondi")
total("beef burger")
# Out:
# 223.6

# %%
#Task 5
def replace_domain(email,new_domain,old_domain="kaaj.com"):
  
  i = email.index('@')+1
  new=""
  changed = True
  if email[i:]==old_domain:
    new=email[:i]+new_domain
    changed = False
  else:
    new = email
  
  result=""
  if changed== True:
    result="Unchanged: "+new
  else:
    result="Changed: "+new
  return result
print(replace_domain('alice@kaaj.com', 'sheba.xyz', 'kaaj.com'))
# Out:
# Changed: alice@sheba.xyz

# %%
def replace_domain(email,new_domain,old_domain="kaaj.com"):
  new = ''
  flag = True
  new1=""
  result = ""
  for i in range (len(email)):
    if email[i]=="@":
      new += email[i+1:]
      new1+= email[:i+1]
  if new==old_domain:
    new1 = new1+new_domain
    flag = False
  else:
    new1 = email 
  if flag==True:
    result = "Unchanged: "+new1
  else:
    result = "Changed: "+new1
 
  return result
print(replace_domain('alice@kaaj.com', 'sheba.xyz', 'kaaj.com'))
print(replace_domain("bob@sheba.xyz","sheba.xyz"))
# Out:
# Changed: alice@sheba.xyz
# Unchanged: bob@sheba.xyz

# %%
email="alice@kaaj.com"
new = ''
new2=""
for i in range (len(email)):
  if email[i]=="@":
    new += email[i+1:]
    new2 +=email[:i+1]
print(new)
print(new2)
# Out:
# kaaj.com
# alice@

# %%
# Task 6
def vow (name):
  name.lower()
  vowel = "aeiou"
  count= 0
  out=""
  lst = []
  for i in name:
    if i in vowel:
      count+=1
      lst.append(i)
  if len(lst)==0:
    print("NO VOWELS IN THE NAME")
  else:
    out+="Vowels: "+",".join(lst)+" .Total num of vow: "+str(count)
  return out
  
print(vow("Steve Jobs"))
# Out:
# Vowels: e,e,o .Total num of vow: 3

# %%
# Task 7
def palindrome_check(name):
  rev=name[::-1]
  if name==rev:
    return "Palindrome"
  else:
    return "Not a palindrome"
palindrome_check("madam")
# Out:
# 'Palindrome'

# %%
# task 8
def funcA(days):
  year = days//365
  days%=365
  months=days//30
  days%=30
  print(year," years,", months," months,",days," days")
funcA(4000)
# Out:
# 10  years, 11  months, 20  days

# %%
#Task 9
def ans(str1):
  s1=str1.capitalize()
  lst=[]
  check = [".","?","!"]
  for i in s1:
    lst.append(i)
  for i in range(len(lst)):
    if lst[i] in check and i<len(lst)-1:
      lst[i+2]=lst[i+2].upper()
    if lst[i]=='i' and lst[i-1]==" " and lst[i+1]==" "and len(lst)-1:
      lst[i]="I"
  return "".join(lst)
print(ans('my favourite animal is a dog. a dog has sharp teeth so that it can eat flesh very easily. do you know my pet dog’s name? i love my pet very much.'))
# Out:
# My favourite animal is a dog. A dog has sharp teeth so that it can eat flesh very easily. Do you know my pet dog’s name? I love my pet very much.
