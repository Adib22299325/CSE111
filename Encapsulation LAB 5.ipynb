# %%
# Task 1
import math
class Circle:
  def __init__(self,rad):
    self.__rad = rad
  def area(self):
    return math.pi*self.__rad**2
  def getRadius(self):
    return self.__rad
  def setRadius(self,r):
    self.__rad = r

c1 = Circle(4)
print("First circle radius:" , c1.getRadius())
print("First circle area:" , c1.area())


c2 = Circle(5)
print("Second circle radius:" , c2.getRadius())
print("Second circle area:" , c2.area())
# Out:
# First circle radius: 4
# First circle area: 50.26548245743669
# Second circle radius: 5
# Second circle area: 78.53981633974483

# %%
# Task 2
class Triangle:
  def __init__(self,b, h):
    self.__b = b
    self.__h = h
  def getBase(self):
    return self.__b
  def setbase(self,b):
    self.__b = b
  def getHeight(self):
    return self.__h
  def setHeight(self,h):
    self.__h = h
  def area(self):
    return 0.5*self.__h*self.__b
t1 = Triangle(10, 5)
print("First Triangle Base:" , t1.getBase())
print("First Triangle Height:" , t1.getHeight())
print("First Triangle area:" ,t1.area())


t2 = Triangle(5, 3)
print("Second Triangle Base:" , t2.getBase())
print("Second Triangle Height:" , t2.getHeight())
print("Second Triangle area:" ,t2.area())
# Out:
# First Triangle Base: 10
# First Triangle Height: 5
# First Triangle area: 25.0
# Second Triangle Base: 5
# Second Triangle Height: 3
# Second Triangle area: 7.5

# %%
# Task 3
class Teacher:
  def __init__(self,naam,dept):
    self.__name = naam
    self.__dept = dept
    self.__info = []
  def addCourse(self,rcvr):
    self.__info.append(rcvr.course)
  def printDetail(self):
    print("===========================")
    print(f"Name {self.__name} \nDept:{self.__dept}")
    print("List of courses")
    print("============================")
    for i in self.__info:
      print(i)
class Course:
  def __init__(self,c):
    self.course = c
    
  
t1 = Teacher("Saad Abdullah", "CSE")
t2 = Teacher("Mumit Khan", "CSE")
t3 = Teacher("Sadia Kazi", "CSE")                          
c1 = Course("CSE 110 Programming Language I")                           
c2 = Course("CSE 111 Programming Language-II")                           
c3 = Course("CSE 220 Data Structures")                           
c4 = Course("CSE 221 Algorithms")                           
c5 = Course("CSE 230 Discrete Mathematics")                           
c6 = Course("CSE 310 Object Oriented Programming")                           
c7 = Course("CSE 320 Data Communications")                          
c8 = Course("CSE 340 Computer Architecture") 
t1.addCourse(c1)
t1.addCourse(c2)
t2.addCourse(c3)
t2.addCourse(c4)
t2.addCourse(c5)
t3.addCourse(c6)
t3.addCourse(c7)
t3.addCourse(c8)
t1.printDetail()
t2.printDetail()
t3.printDetail()
# Out:
# ...
# Name Saad Abdullah
# Dept:CSE
# List of courses
# ...
# CSE 110 Programming Language I
# CSE 111 Programming Language-II
# ...
# Name Mumit Khan
# Dept:CSE
# List of courses
# ...
# CSE 220 Data Structures
# CSE 221 Algorithms
# CSE 230 Discrete Mathematics
# ...
# Name Sadia Kazi
# Dept:CSE
# List of courses
# ...
# CSE 310 Object Oriented Programming
# CSE 320 Data Communications
# CSE 340 Computer Architecture

# %%
# Task 4
class Team:
  def __init__(self,team =None):
    self.__team = team
    self.__list = []
  def setName(self,team):
    self.__team = team
  def addPlayer(self,p):
    self.__list.append(p.player)
  def printDetail(self):
    print("====================================")
    print("Team:",self.__team)
    print("List of players:")
    print(self.__list)

class Player:
  def __init__(self,p):
    self.player = p
    
b = Team()
b.setName('Bangladesh')
mashrafi = Player("Mashrafi")
b.addPlayer(mashrafi)
tamim = Player("Tamim")
b.addPlayer(tamim)
b.printDetail()
a = Team("Australia")
ponting = Player("Ponting")
a.addPlayer(ponting)
lee = Player("Lee")
a.addPlayer(lee)
a.printDetail()
# Out:
# ...
# Team: Bangladesh
# List of players:
# ['Mashrafi', 'Tamim']
# ...
# Team: Australia
# List of players:
# ['Ponting', 'Lee']

# %%
# Task 5
class Usis:
  def __init__(self):
    print("USIS is ready to use!")
  def login(self,stud):
    if stud.email==None and stud.password==None:
      print("Email and password need to be set.")
    else:
      print("Login successful!")
      self.logSta = True
  def advising(self,*stud):
    if len(stud)==1:
      if stud[0].logSta == None:
        print("Please login to advise courses!")
      else:
        print("You haven't selected any courses.")

    else:
      self.studeent = stud[1:]
      if len(stud[1:])>1 and  len(stud[1:])<=3:
        print("Advising successful!")
      elif len (stud[1:])>=3:
        print("You need special approval to take more than 3 courses.")
      
  def individualDetails(self,stud):
    return f"Name:{stud.name} \nID:{stud.id} \nDepartment:{stud.dept}\nAdvised courses: {', '.join(self.studeent)}"

class Student:
  def __init__(self,name,id,dept):
    self.name = name
    self.id = id
    self.dept = dept
    self.email = None
    self.password = None
    self.logSta = None
    print("Student object is created!")
rakib = Student("Rakib", 12301455, "CSE")
print("1***********************")
usis_obj = Usis()
print("2***********************")
usis_obj.login(rakib)
print("3***********************")
usis_obj.advising(rakib)
print("4***********************")
rakib.email = "rakib@hotmail.com"
rakib.password = "1234"
print("5***********************")
usis_obj.login(rakib)
print("6***********************")
usis_obj.advising(rakib)
print("7***********************")
usis_obj.advising(rakib, "CSE110", "PHY111", "MAT110", "CSE260")
print("8***********************")
usis_obj.advising(rakib, "CSE110", "PHY111", "MAT110")
print("9***********************")
print(usis_obj.individualDetails(rakib))
# Out:
# Student object is created!
# 1***********************
# USIS is ready to use!
# 2***********************
# Email and password need to be set.
# 3***********************
# Please login to advise courses!
# 4***********************
# 5***********************
# Login successful!
# 6***********************
# Please login to advise courses!
# 7***********************
# You need special approval to take more than 3 courses.
# 8***********************
# Advising successful!
# 9***********************
# Name:Rakib
# ID:12301455
# Department:CSE
# Advised courses: CSE110, PHY111, MAT110

# %%
# Task 6
class Train:
  def __init__(self,name,*routes):
    self.name = name
    self.routes = routes
    print("Welcome aboard on",self.name)
    print("Start:",self.routes[0])
    print("Destination:",self.routes[-1])
    self.psgr = []
  def addPassenger(self,*passenger):
    for p in passenger:
      self.psgr.append(p)
      print(p.name,"welcome abroad")
      if p.start=="Default":
        p.start = self.routes[0]
      if p.stop=="Default":
        p.stop = self.routes[-1]
  
  def allPassengerDetails(self):
    for p in self.psgr:
      startIndex = self.routes.index(p.start)
      endIndex = self.routes.index(p.stop)
      fare = (endIndex-startIndex)*100
      print(f"Name: {p.name}, Start: {p.start}, Destination: {p.stop}, Fare: ${fare}")
class Passenger:
  def __init__(self,name,start = "Default",stop="Default"):
    self.name = name
    self.start = start
    self.stop = stop
t1 = Train('T1-Express','New York','Manhattan','Brooklyn','Boston')
print("1========================")
p1 =Passenger("Naruto")
t1.addPassenger(p1)
p2 = Passenger("Sasuke","Manhattan")
p3 = Passenger("Hinata","Manhattan","Brooklyn")
print("2========================")
t1.addPassenger(p2,p3)
print("3========================")
t1.allPassengerDetails()
print("4========================")
t2 = Train('Europe-Express','London','Paris','Brussels','Turkey')
print("5========================")
p4 =Passenger("Max","London","Brussels")
p5 = Passenger("Eleven","Paris")
p6 = Passenger("Mike","Brussels")
t2.addPassenger(p4,p5,p6)
print("6========================")
t2.allPassengerDetails()
# Out:
# Welcome aboard on T1-Express
# Start: New York
# Destination: Boston
# 1========================
# Naruto welcome abroad
# 2========================
# Sasuke welcome abroad
# Hinata welcome abroad
# 3========================
# Name: Naruto, Start: New York, Destination: Boston, Fare: $300
# Name: Sasuke, Start: Manhattan, Destination: Boston, Fare: $200
# Name: Hinata, Start: Manhattan, Destination: Brooklyn, Fare: $100
# 4========================
# Welcome aboard on Europe-Express
# Start: London
# Destination: Turkey
# 5========================
# Max welcome abroad
# Eleven welcome abroad
# Mike welcome abroad
# 6========================
# Name: Max, Start: London, Destination: Brussels, Fare: $200
# Name: Eleven, Start: Paris, Destination: Turkey, Fare: $200
# Name: Mike, Start: Brussels, Destination: Turkey, Fare: $100

# %%
# Task 7
class BracuStudent:
  def __init__(self,name,home):
    self.name = name
    self.home = home
    self.b_pass = False
  def show_details(self):
    print("Student name:",self.name)
    print("Lives in",self.home)
    print("Have Bus Pass?",self.b_pass)
  def get_pass(self):
    self.b_pass = True
class BracuBus:
  def __init__(self,dest,capacity = 2):
    self.dest = dest
    self.capacity = capacity
    self.passengers = []
  def show_details(self):
    print("Bus Route:",self.dest)
    print(f"Passengers Count:{len(self.passengers)} (Max:{self.capacity})")
    print("Passengers On Board:",self.passengers)
  def board(self,*passengers):
    if not passengers:
      print("No passenger!")  
    else:
      for stud in passengers:
        if stud.b_pass == False:
          print("You don't have bus pass!")
        elif stud.home!=self.dest:
          print("You got on wrong bus!")
        elif len(self.passengers) >= self.capacity:
          print("Bus is full!")
        else:
          print(stud.name, "boarded the bus.")
          self.passengers.append(stud.name)
st1 = BracuStudent("Afif", "Mirpur")
print("1===========================")
st2 = BracuStudent("Shanto", "Motijheel")
st3 = BracuStudent("Taskin", "Mirpur")
st1.show_details()
st2.show_details()
print("2===========================")
st3.show_details()
print("3===========================")
bus1 = BracuBus("Mirpur")
bus2 = BracuBus("Azimpur", 5)
bus1.show_details()
bus2.show_details()
print("4===========================")
st2.get_pass()
st3.get_pass()
print("5===========================")
st2.show_details()
st3.show_details()
print("6===========================")
bus1.board()
print("7===========================")
bus1.board(st1, st2)
print("8===========================")
st1.get_pass()
st2.home = "Mirpur"
st1.show_details()
st2.show_details()
print("9===========================")
bus1.board(st1, st2, st3)
print("10===========================")
bus1.show_details()
# Out:
# 1===========================
# Student name: Afif
# Lives in Mirpur
# Have Bus Pass? False
# Student name: Shanto
# Lives in Motijheel
# Have Bus Pass? False
# 2===========================
# Student name: Taskin
# Lives in Mirpur
# Have Bus Pass? False
# 3===========================
# Bus Route: Mirpur
# Passengers Count:0 (Max:2)
# Passengers On Board: []
# Bus Route: Azimpur
# Passengers Count:0 (Max:5)
# Passengers On Board: []
# 4===========================
# 5===========================
# Student name: Shanto
# Lives in Motijheel
# Have Bus Pass? True
# Student name: Taskin
# Lives in Mirpur
# Have Bus Pass? True
# 6===========================
# No passenger!
# 7===========================
# You don't have bus pass!
# You got on wrong bus!
# 8===========================
# Student name: Afif
# Lives in Mirpur
# Have Bus Pass? True
# Student name: Shanto
# Lives in Mirpur
# Have Bus Pass? True
# 9===========================
# Afif boarded the bus.
# Shanto boarded the bus.
# ...

# %%
# Task 8
class Library:
      def __init__(self,location,dictionary):
          self.location=location 
          self.dictionary=dictionary 
          self.borrower={} 
      def details(self):
          print(self.location,"library details")
          print(f"Borrower details:\n{self.borrower}")  
          print(f"Books availability:\n{self.dictionary}")  

class Reader:
    def __init__(self,name):
        self.name=name 
        self.list_topics=[]
        self.borrowed_books=[]
        self.dict_uncommon={}

    def borrow(self,library,*topics): 
        for i in topics:
            self.list_topics.append(i) 
            if library.dictionary[i] > 0 and len(self.list_topics)<5:
               library.dictionary[i] -= 1
            if library.dictionary[i]<=0:
               print(f"{i} books are not available at the moment.")
               continue
            if len(self.list_topics)<5:
                self.borrowed_books.append(i)
                print(i,"book is borrowed succesfully.")
            else:
                print("You cannot borrow more than 5 books.")
       
    def readerInfo(self,book_type=None):
        for i in self.borrowed_books:
            if i not in self.dict_uncommon:
                self.dict_uncommon[i]=1
            else:
                self.dict_uncommon[i]+=1
        if book_type==None:
            print(f"{self.name},you have {len(self.borrowed_books)} book(s) with you.")
            for i in self.dict_uncommon:
                print(i, ":", self.dict_uncommon[i])
        else:
            print(self.borrowed_books)
            
            print(self.name ,book_type, self.dict_uncommon[book_type])


L1=Library('Dhaka',{'Arts':15,'Fiction':135,'Politics':2,'Science':11,'Poetry':15})
L1.details()
print("1----------------------")
r1=Reader('Aladdin')
r1.borrow(L1,'Arts','Fiction','Fiction','Politics')
print("2----------------------")
r1.borrow(L1,'Politics','Fiction')
print("3----------------------")
r1.readerInfo()
print("4----------------------")
r1.readerInfo('Fiction')
print("5----------------------")
L1.details()
print("6----------------------")
r2=Reader('Jasmine')
r2.borrow(L1,'Politics','Poetry')
print("7----------------------")
r2.readerInfo()
print("8----------------------")
L1.details()
# Out:
# Dhaka library details
# Borrower details:
# {}
# Books availability:
# {'Arts': 15, 'Fiction': 135, 'Politics': 2, 'Science': 11, 'Poetry': 15}
# 1----------------------
# Arts book is borrowed succesfully.
# Fiction book is borrowed succesfully.
# Fiction book is borrowed succesfully.
# Politics book is borrowed succesfully.
# 2----------------------
# You cannot borrow more than 5 books.
# You cannot borrow more than 5 books.
# 3----------------------
# Aladdin,you have 4 book(s) with you.
# Arts : 1
# Fiction : 2
# Politics : 1
# 4----------------------
# ['Arts', 'Fiction', 'Fiction', 'Politics']
# Aladdin Fiction 4
# 5----------------------
# Dhaka library details
# Borrower details:
# {}
# Books availability:
# {'Arts': 14, 'Fiction': 133, 'Politics': 1, 'Science': 11, 'Poetry': 15}
# 6----------------------
# Politics books are not available at the moment.
# Poetry book is borrowed succesfully.
# 7----------------------
# Jasmine,you have 1 book(s) with you.
# Poetry : 1
# ...

# %%
#Task-8
class Library:
    def __init__(self, location, book_availability):
        self.location = location
        self.borrower_info = {}
        self.book_availability = book_availability
    def details(self):
        print(f"{self.location} Library details")
        print("Borrower details:")
        print(self.borrower_info)
        print("Books availability:")
        print(self.book_availability)
class Reader:
    def __init__(self, name):
        self.name = name
        self.borrowed_books = {}
    def borrow(self, library, *book_types):
        for i in book_types:
            if i not in library.book_availability:
                print(f"{i} books are not available at the moment.")
                continue
            if library.book_availability[i] == 0:
                print(f"No {i} book is available at the moment.")
                continue
            if self.name not in library.borrower_info:
                library.borrower_info[self.name] = 0
            if library.borrower_info[self.name] + 1 > 5:
                print("You cannot borrow more than 5 books.")
                continue
            library.book_availability[i] -= 1
            library.borrower_info[self.name] += 1
            if i not in self.borrowed_books:
                self.borrowed_books[i] = 0
            self.borrowed_books[i] += 1
            print(f"{i} book is borrowed successfully.")
    def readerInfo(self, book_type=None):
        if book_type is None:
            print(f"{self.name}, you have {sum(self.borrowed_books.values())} book(s) with you.")
            for i, j in self.borrowed_books.items():
                print(f"Books on {i}: {j}")
        else:
            num_books = self.borrowed_books.get(book_type, 0)
            print(f"{self.name}, you have {num_books} {book_type} book(s) with you.")
L1=Library('Dhaka',{'Arts':15,'Fiction':135,'Politics':2,'Science':11,'Poetry':15})
L1.details()
print("1----------------------")
r1=Reader('Aladdin')
r1.borrow(L1,'Arts','Fiction','Fiction','Politics')
print("2----------------------")
r1.borrow(L1,'Politics','Fiction')
print("3----------------------")
r1.readerInfo()
print("4----------------------")
r1.readerInfo('Fiction')
print("5----------------------")
L1.details()
print("6----------------------")
r2=Reader('Jasmine')
r2.borrow(L1,'Politics','Poetry')
print("7----------------------")
r2.readerInfo()
print("8----------------------")
L1.details()
# Out:
# Dhaka Library details
# Borrower details:
# {}
# Books availability:
# {'Arts': 15, 'Fiction': 135, 'Politics': 2, 'Science': 11, 'Poetry': 15}
# 1----------------------
# Arts book is borrowed successfully.
# Fiction book is borrowed successfully.
# Fiction book is borrowed successfully.
# Politics book is borrowed successfully.
# 2----------------------
# Politics book is borrowed successfully.
# You cannot borrow more than 5 books.
# 3----------------------
# Aladdin, you have 5 book(s) with you.
# Books on Arts: 1
# Books on Fiction: 2
# Books on Politics: 2
# 4----------------------
# Aladdin, you have 2 Fiction book(s) with you.
# 5----------------------
# Dhaka Library details
# Borrower details:
# {'Aladdin': 5}
# Books availability:
# {'Arts': 14, 'Fiction': 133, 'Politics': 0, 'Science': 11, 'Poetry': 15}
# 6----------------------
# No Politics book is available at the moment.
# Poetry book is borrowed successfully.
# 7----------------------
# ...
